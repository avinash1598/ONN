# %%
# %load_ext autoreload
# %autoreload 2

import json
from os import path

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

from tbd_eeg.data_analysis.eegutils import EEGexp
from glob import glob

datastore = '/home/jupyter-avinash/datastore/allen_mouse_eeg'
#pip install -e .
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
cwd = os.getcwd()
print(cwd)
# Out:
# /home/jupyter-avinash/ranjan_env/mouse_brain_project/hopf_oscillator

# %%
so_many_mouse = glob(datastore+"/mouse*")

for mouse in so_many_mouse:
    sessions = [path.basename(f) for f in glob(path.join(mouse, '*'))]
    print(sessions)
    
    for expt in sessions:
        if expt != 'histology':
            rec_folder = path.join(mouse, expt, 'experiment1/recording1')
            print(rec_folder)
            exp = EEGexp(rec_folder, preprocess=False, make_stim_csv=False)
            print(exp.ephys_params['EEG'])
# Out:
# ['estim_vis_2021-01-22_11-07-12', 'histology', 'signal_test_2021-01-14_13-42-04', 'stim_test_2021-01-22_10-38-03']
# /home/jupyter-avinash/datastore/allen_mouse_eeg/mouse551400/estim_vis_2021-01-22_11-07-12/experiment1/recording1
# Experiment type: sensory stimulation
# SomnoSuite log file not found.
# Body camera file not found.
# Pupil camera file not found.
# {'sample_rate': 2500, 'num_chs': 40, 'bit_volts': 0.19499999284744263, 'units': 'uV', 'continuous': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse551400/estim_vis_2021-01-22_11-07-12/experiment1/recording1/continuous/Rhythm_FPGA-156.0/continuous.dat', 'timestamps': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse551400/estim_vis_2021-01-22_11-07-12/experiment1/recording1/continuous/Rhythm_FPGA-156.0/timestamps_master_clock.npy'}
# /home/jupyter-avinash/datastore/allen_mouse_eeg/mouse551400/signal_test_2021-01-14_13-42-04/experiment1/recording1
# Experiment type: sensory stimulation
# SomnoSuite log file not found.
# Body camera file not found.
# Pupil camera file not found.
# {'sample_rate': 2500, 'num_chs': 40, 'bit_volts': 0.19499999284744263, 'units': 'uV', 'continuous': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse551400/signal_test_2021-01-14_13-42-04/experiment1/recording1/continuous/Rhythm_FPGA-156.0/continuous.dat', 'timestamps': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse551400/signal_test_2021-01-14_13-42-04/experiment1/recording1/continuous/Rhythm_FPGA-156.0/timestamps_master_clock.npy'}
# /home/jupyter-avinash/datastore/allen_mouse_eeg/mouse551400/stim_test_2021-01-22_10-38-03/experiment1/recording1
# No *stim* files were found.
# Experiment type: spontaneous
# SomnoSuite log file not found.
# Body camera file not found.
# Pupil camera file not found.
# {'sample_rate': 2500, 'num_chs': 40, 'bit_volts': 0.19499999284744263, 'units': 'uV', 'continuous': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse551400/stim_test_2021-01-22_10-38-03/experiment1/recording1/continuous/Rhythm_FPGA-156.0/continuous.dat', 'timestamps': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse551400/stim_test_2021-01-22_10-38-03/experiment1/recording1/continuous/Rhythm_FPGA-156.0/timestamps_master_clock.npy'}
# ['estim_vis_2021-07-29_10-37-41', 'histology', 'signal_test2_2021-07-13_14-33-12', 'signal_test_2021-07-12_09-06-27']
# /home/jupyter-avinash/datastore/allen_mouse_eeg/mouse586466/estim_vis_2021-07-29_10-37-41/experiment1/recording1
# This data does not contain an EEG recording.
# Experiment type: sensory stimulation
# SomnoSuite log file not found.
# Body camera file not found.
# Pupil camera file not found.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [3], in <cell line: 3>()
#      10 print(rec_folder)
#      11 exp = EEGexp(rec_folder, preprocess=False, make_stim_csv=False)
# ---> 12 print(exp.ephys_params['EEG'])
#
# KeyError: 'EEG'

# %%
mouse = 'mouse599975'

print('Available sessions:')
print([path.basename(f) for f in glob(path.join(datastore, mouse, '*'))])
# Out:
# Available sessions:
# ['estim_vis_2022-03-31_12-03-06', 'histology', 'signal_test_2022-02-08_13-19-49', 'urethane_vis_2022-04-01_10-58-41']

# %%
expt = 'estim_vis_2022-03-31_12-03-06'

rec_folder = path.join(datastore, mouse, expt, 'experiment1/recording1')
exp = EEGexp(rec_folder, preprocess=False, make_stim_csv=False)

print(exp.ephys_params['EEG'])
# Out:
# {'probeB': {'probe_info': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse599975/estim_vis_2022-03-31_12-03-06/experiment1/probeB_sorted/probe_info.json', 'num_chs': 384, 'bit_volts': 0.195, 'ap_continuous': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse599975/estim_vis_2022-03-31_12-03-06/experiment1/probeB_sorted/continuous/Neuropix-PXI-100.0/continuous.dat', 'ap_timestamps': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse599975/estim_vis_2022-03-31_12-03-06/experiment1/probeB_sorted/continuous/Neuropix-PXI-100.0/timestamps_master_clock.npy', 'ap_sample_rate': 30000, 'lfp_continuous': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse599975/estim_vis_2022-03-31_12-03-06/experiment1/probeB_sorted/continuous/Neuropix-PXI-100.1/continuous.dat', 'lfp_timestamps': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse599975/estim_vis_2022-03-31_12-03-06/experiment1/probeB_sorted/continuous/Neuropix-PXI-100.1/timestamps_master_clock.npy', 'lfp_sample_rate': 2500, 'spike_clusters': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse599975/estim_vis_2022-03-31_12-03-06/experiment1/probeB_sorted/continuous/Neuropix-PXI-100.0/spike_clusters.npy', 'spike_times': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse599975/estim_vis_2022-03-31_12-03-06/experiment1/probeB_sorted/continuous/Neuropix-PXI-100.0/spike_times_master_clock.npy', 'cluster_group': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse599975/estim_vis_2022-03-31_12-03-06/experiment1/probeB_sorted/continuous/Neuropix-PXI-100.0/cluster_group.tsv', 'cluster_metrics': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse599975/estim_vis_2022-03-31_12-03-06/experiment1/probeB_sorted/continuous/Neuropix-PXI-100.0/metrics.csv', 'waveforms': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse599975/estim_vis_2022-03-31_12-03-06/experiment1/probeB_sorted/continuous/Neuropix-PXI-100.0/mean_waveforms.npy'}, 'probeC': {'probe_info': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse599975/estim_vis_2022-03-31_12-03-06/experiment1/probeC_sorted/probe_info.json', 'num_chs': 384, 'bit_volts': 0.195, 'ap_continuous': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse599975/estim_vis_2022-03-31_12-03-06/experiment1/probeC_sorted/continuous/Neuropix-PXI-100.0/continuous.dat', 'ap_timestamps': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse599975/estim_vis_2022-03-31_12-03-06/experiment1/probeC_sorted/continuous/Neuropix-PXI-100.0/timestamps_master_clock.npy', 'ap_sample_rate': 30000, 'lfp_continuous': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse599975/estim_vis_2022-03-31_12-03-06/experiment1/probeC_sorted/continuous/Neuropix-PXI-100.1/continuous.dat', 'lfp_timestamps': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse599975/estim_vis_2022-03-31_12-03-06/experiment1/probeC_sorted/continuous/Neuropix-PXI-100.1/timestamps_master_clock.npy', 'lfp_sample_rate': 2500, 'spike_clusters': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse599975/estim_vis_2022-03-31_12-03-06/experiment1/probeC_sorted/continuous/Neuropix-PXI-100.0/spike_clusters.npy', 'spike_times': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse599975/estim_vis_2022-03-31_12-03-06/experiment1/probeC_sorted/continuous/Neuropix-PXI-100.0/spike_times_master_clock.npy', 'cluster_group': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse599975/estim_vis_2022-03-31_12-03-06/experiment1/probeC_sorted/continuous/Neuropix-PXI-100.0/cluster_group.tsv', 'cluster_metrics': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse599975/estim_vis_2022-03-31_12-03-06/experiment1/probeC_sorted/continuous/Neuropix-PXI-100.0/metrics.csv', 'waveforms': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse599975/estim_vis_2022-03-31_12-03-06/experiment1/probeC_sorted/continuous/Neuropix-PXI-100.0/mean_waveforms.npy'}, 'probeF': {'probe_info': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse599975/estim_vis_2022-03-31_12-03-06/experiment1/probeF_sorted/probe_info. ...
# Experiment type: sensory stimulation
# SomnoSuite log file not found.
# Body camera file not found.
# Pupil camera file not found.
# {'sample_rate': 500, 'num_chs': 40, 'bit_volts': 0.19499999284744263, 'units': 'uV', 'continuous': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse599975/estim_vis_2022-03-31_12-03-06/experiment1/recording1/continuous/Rhythm_FPGA-101.0/continuous.dat', 'timestamps': '/home/jupyter-avinash/datastore/allen_mouse_eeg/mouse599975/estim_vis_2022-03-31_12-03-06/experiment1/recording1/continuous/Rhythm_FPGA-101.0/timestamps_master_clock.npy'}

# %%
print(exp.stimulus_log_file)

#Deafult sampling rate si 250 and not 2500 - rhythm_info, structure.oebin
## loading the EEG data
eegdata = exp.load_eegdata(return_type='pd', downsamplefactor=1)
eegdata.head()
# Out:
# /home/jupyter-avinash/datastore/allen_mouse_eeg/mouse599975/estim_vis_2022-03-31_12-03-06/experiment1/recording1/sensory_stim_log.csv
#                   0          1          2          3          4          5   \
# 12.487579 -21.839999  -0.195000  22.619999 -41.729998 -20.279999  15.209999
# 12.489579  -7.800000  27.104999  44.264998   0.000000   9.750000  42.314998
# 12.491579  -1.170000  37.439999  61.229998  26.519999  49.724998  69.224997
# 12.493579  22.034999  34.709999  52.259998  38.804999  45.629998  62.789998
# 12.495579  22.814999  27.104999  44.264998  46.019998  53.039998  58.499998
#
#                   6          7          8          9          10         11  \
# 12.487579 -27.689999 -20.279999  -8.580000 -23.204999 -17.744999 -20.669999
# 12.489579  -5.850000  29.249999  38.219999  21.254999  28.664999  26.324999
# 12.491579  22.424999  48.749998  57.719998  34.514999  43.094998  34.904999
# 12.493579  28.664999  52.454998  62.009998  33.929999  50.699998  44.654998
# 12.495579  23.399999  54.014998  62.789998  30.809999  54.794998  44.069998
#
#                   12         13         14         15         16         17  \
# 12.487579 -15.209999 -34.514999 -36.659999 -47.384998 -38.999999 -28.859999
# 12.489579  25.739999  14.429999   3.900000   0.195000  -1.755000  15.404999
# 12.491579  36.464999  22.229999  14.624999   2.730000 -15.599999  19.304999
# 12.493579  48.359998  37.244999  28.274999  11.700000 -12.285000  27.884999
# 12.495579  62.789998  48.944998  38.024999  24.374999   2.730000  45.629998
#
#                   18         19         20         21         22         23  \
# 12.487579 -58.499998 -26.324999 -85.409997   7.605000 -61.229998 -89.894997
# 12.489579 -18.719999  11.505000 -33.734999  50.894998  -1.560000 -32.564999
# 12.491579 -45.239998  14.039999 -27.494999  76.244997  43.874998  33.344999
# 12.493579 -42.314998  13.649999 -23.984999  78.584997  62.204998  38.219999
# 12.495579   1.755000  52.064998  24.179999  78.779997  78.974997  49.334998
#
#                   24         25         26         27         28         29
# 12.487579  11.700000 -77.024997 -88.724997  14.234999 -30.224999 -69.224997
# 12.489579  47.189998  -5.070000 -30.809999  39.194999  13.844999 -19.109999
# 12.491579  81.119997  49.139998  -6.630000  60.059998  32.174999 -15.404999
# 12.493579  82.484997  67.859998  -3.315000  59.669998  45.629998  -4.875000
# 12.495579  72.734997  70.979997  15.794999  50.504998  50.114998  -1.950000

# %%
eegdata
# Out:
#                      0          1          2           3           4   \
# 12.487579    -21.839999  -0.195000  22.619999  -41.729998  -20.279999
# 12.489579     -7.800000  27.104999  44.264998    0.000000    9.750000
# 12.491579     -1.170000  37.439999  61.229998   26.519999   49.724998
# 12.493579     22.034999  34.709999  52.259998   38.804999   45.629998
# 12.495579     22.814999  27.104999  44.264998   46.019998   53.039998
# ...                 ...        ...        ...         ...         ...
# 5309.629248   45.824998  47.774998  33.929999   -2.535000   42.899998
# 5309.631248   61.229998  52.844998  43.874998    5.070000   59.084998
# 5309.633248  108.029996  62.399998  57.914998   34.319999   98.669996
# 5309.635248  129.674995  75.464997  75.074997   84.824997  138.839995
# 5309.637248  127.529995  89.309997  91.064997  115.049996  164.384994
#
#                      5           6           7           8           9   \
# 12.487579     15.209999  -27.689999  -20.279999   -8.580000  -23.204999
# 12.489579     42.314998   -5.850000   29.249999   38.219999   21.254999
# 12.491579     69.224997   22.424999   48.749998   57.719998   34.514999
# 12.493579     62.789998   28.664999   52.454998   62.009998   33.929999
# 12.495579     58.499998   23.399999   54.014998   62.789998   30.809999
# ...                 ...         ...         ...         ...         ...
# 5309.629248   67.469998   98.864996   74.879997   66.104998   80.924997
# 5309.631248   77.414997  122.654996   92.039997   80.924997   97.499996
# 5309.633248  103.154996  155.219994  121.289996  108.809996  122.849995
# 5309.635248  135.524995  176.279994  155.609994  147.809995  152.099994
# 5309.637248  156.584994  180.764993  177.839993  174.719994  166.334994
#
#                      10          11          12          13          14  \
# 12.487579    -17.744999  -20.669999  -15.209999  -34.514999  -36.659999
# 12.489579     28.664999   26.324999   25.739999   14.429999    3.900000
# 12.491579     43.094998   34.904999   36.464999   22.229999   14.624999
# 12.493579     50.699998   44.654998   48.359998   37.244999   28.274999
# 12.495579     54.794998   44.069998   62.789998   48.944998   38.024999
# ...                 ...         ...         ...         ...         ...
# 5309.629248   67.469998   70.004997  101.984996   50.309998  125.579995
# 5309.631248   89.504997   91.649997  128.309995   62.594998  141.959995
# 5309.633248  113.879996  118.754996  158.729994   87.944997  164.189994
# 5309.635248  151.904994  154.439994  198.119993  124.409995  201.824993
# 5309.637248  174.134994  165.164994  211.769992  145.274995  213.329992
#
#                      15          16          17          18          19  \
# 12.487579    -47.384998  -38.999999  -28.859999  -58.499998  -26.324999
# 12.489579      0.195000   -1.755000   15.404999  -18.719999   11.505000
# 12.491579      2.730000  -15.599999   19.304999  -45.239998   14.039999
# 12.493579     11.700000  -12.285000   27.884999  -42.314998   13.649999
# 12.495579     24.374999    2.730000   45.629998    1.755000   52.064998
# ...                 ...         ...         ...         ...         ...
# 5309.629248  169.259994  187.784993  136.499995  170.429994  145.469995
# 5309.631248  181.544993  191.879993  151.319994  163.604994  147.419995
# 5309.633248  206.894992  211.769992  183.884993  175.694994  171.404994
# 5309.635248  234.584991  236.339991  222.884992  211.574992  212.354992
# 5309.637248  230.879992  225.809992  227.954992  223.664992  227.564992
#
#                      20          21          22          23          24  \
# 12.487579    -85.409997    7.605000  -61.229998  -89.894997   11.700000
# 12.489579    -33.734999   50.894998   -1.560000  -32.564999   47.189998
# 12.491579    -27.494999   76.244997   43.874998   33.344999   81.119997
# 12.493579    -23.984999   78.584997   62.204998   38.219999   82.484997
# 12.495579     24.179999   78.779997   78.974997   49.334998   72.734997
# ...                 ...         ...         ...         ...         ...
# 5309.629248  189.734993  100.229996  173.939994  218.789992   76.634997
# 5309.631248  187.589993  110.759996  187.784993  232.244991   87.749997
# 5309.633248  192.269993  143.519995  216.644992  258.569991  116.609996
# 5309.635248  219.569992  183.494993  243.749991  275.534990  151.319994
# 5309.637248  223.274992  197.339993  225.614992  240.434991  167.114994
#
#                      25          26          27          28          29
# 12.487579    -77.024997  -88.724997   14.234999  -30.224999  -69.224997
# 12.489579     -5.070000  -30.809999   39.194999   13.844999  -19.109999
# 12.491579     49.139998   -6.630000   60.059998   32.174999  -15.404999
# 12.493579     67.859998   -3.315000   59.669998   45.629998   -4.875000
# 12.495579     70.979997   15.794999   50.504998   50.114998   -1.950000
# ...                 ...         ...         ...         ...         ...
# 5309.629248  173.744994  196.949993   33.929999   45.044998   92.624997
# 5309.631248  176.279994  188.954993   39.389999   45.629998   87.554997
# 5309.633248  217.814992  222.104992   63.764998   70.199997  109.394996
# 5309.635248  235.559991  230.294992   95.159997   96.719996  117.974996
# 5309.637248  215.864992  179.204993  107.249996  111.734996  105.689996
#
# [2648576 rows x 30 columns]

# %%
X = eegdata
X{0, 0}
plt.plot(X[:,0], X[:,1])
# Out:
#   Input In [22]
#     X{0, 0}
#      ^
# SyntaxError: invalid syntax

# %%
debug
# Out:
# > /srv/data/datastore/common_libs/tbd_eeg/tbd_eeg/data_analysis/eeg_preprocessing.py(263)downsample_eeg_and_timestamps()
#     261
#     262     data_folder = exp.data_folder
# --> 263     new_sample_rate = int(exp.ephys_params['EEG']['sample_rate']/downsamplefactor)
#     264     data_name = 'data_' + str(int(new_sample_rate)) + 'Hz.npy'
#     265     ts_name = 'timestamps_master_' + str(int(new_sample_rate)) + 'Hz.npy'
# ipdb>  exp.ephys_params['EEG']['sample_rate']
# 500
# ipdb>  downsamplefactor
# 0
# ipdb>  quit
